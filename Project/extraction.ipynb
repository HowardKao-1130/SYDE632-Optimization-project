# %%
import csv
# Define the CSV file path
csv_file_path = "results_on_cancer_dataset_with_seed_20_and_KKT.csv"

# Define the column indices for the columns of interest
# column_indices = [4 , 5]  # Assuming columns are 0-indexed
column_indices = [9]  # Assuming columns are 0-indexed

# Read the CSV file and extract the rows with highest values in the specified columns
highest_values = 0
rows_with_highest_values = [None]

with open(csv_file_path, "r") as file:
    csv_reader = csv.reader(file)
    header = next(csv_reader)
    for row in csv_reader:
        sum = 0
        for i, col_idx in enumerate(column_indices):
            sum += float(row[col_idx])
            if sum >= highest_values:
                highest_values = sum
                # print(highest_values)

with open(csv_file_path, "r") as file:
    csv_reader = csv.reader(file)
    header = next(csv_reader)
    for row in csv_reader:
        sum = 0
        for i, col_idx in enumerate(column_indices):
            sum += float(row[col_idx])
            if sum >= highest_values:
                # print("HV: ", highest_values)
                rows_with_highest_values.append([row[0], row[1], row[2], row[3], row[4], row[5], row[6], row[7], row[8], row[9]])

# Print the rows with highest values
for row in rows_with_highest_values:
    print(row)
# Out:
# None
# ['1', '1e-06', '0.001', '0.001', '0.9907407407407407', '0.9965986394557823', '0.9333333333333333', '0.9122807017543859', '1.0', '0.8076923076923077']
# ['8', '1e-06', '0.01', '0.001', '0.9907407407407407', '0.9965986394557823', '0.9333333333333333', '0.9122807017543859', '1.0', '0.8076923076923077']
# ['15', '1e-06', '0.1', '0.001', '0.9907407407407407', '0.9965986394557823', '0.9333333333333333', '0.9122807017543859', '1.0', '0.8076923076923077']
# ['22', '1e-06', '1', '0.001', '0.9907407407407407', '0.9965986394557823', '0.9333333333333333', '0.9122807017543859', '1.0', '0.8076923076923077']
# ['29', '1e-06', '10', '0.001', '0.9876543209876543', '0.9897959183673469', '0.9666666666666667', '0.9122807017543859', '1.0', '0.8076923076923077']
# ['36', '1e-06', '100', '0.001', '0.9876543209876543', '0.9897959183673469', '0.9666666666666667', '0.9122807017543859', '1.0', '0.8076923076923077']
# ...
